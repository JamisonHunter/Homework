# %% [markdown]
# Jamison Hunter
#
# June 12, 2023
#
# # Describing Distributions

# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# setting the style for seaborn graphs
plt.style.use(['dark_background','seaborn-muted', 'seaborn-poster'])
# Out:
# C:\Users\Jamison\AppData\Local\Temp\ipykernel_15480\4155392682.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(['dark_background','seaborn-muted', 'seaborn-poster'])
# C:\Users\Jamison\AppData\Local\Temp\ipykernel_15480\4155392682.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(['dark_background','seaborn-muted', 'seaborn-poster'])

# %%
# gathering file path to transform into a data frame
path = r"C:\Users\Jamison\Desktop\CODINGDOJO\data\data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
mean = df['VitD_levels'].mean()
std = df['VitD_levels'].std()
median = df['VitD_levels'].median()
plus_one_std = mean + std
minus_one_std = mean - std

ax = sns.histplot(data=df, x='VitD_levels', discrete=True, stat='density', kde = True);

ax.axvline(mean, color = "red", label = "Mean");
ax.axvline(median, ls='--', color = "green", label = "Median");
ax.axvline(plus_one_std, color = "black");
ax.axvline(minus_one_std, color = "black");
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_ylabel("Density")
ax.set_xlabel("Vitamin D Levels")
ax.set_title("Vitamin D Distribution")
ax.legend()

# %%
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
print(kurt)
if round(kurt) > 3:
    print("Leptokurtic")
if round(kurt) < 3:
    print("Platykurtic")
if round(kurt) == 3:
    print("Mesokurtic")
# Out:
# 3.013147515833447
# Mesokurtic

# %%
print("The above graph is discrete with essentially no skew.")
# Out:
# The above graph is discrete with essentially no skew.

# %%
col = 'Doc_visits'

mean = df[col].mean()
std = df[col].std()
median = df[col].median()
plus_one_std = mean + std
minus_one_std = mean - std

ax = sns.histplot(data=df, x=col, discrete=True, stat='density', kde = True);

ax.axvline(mean, color = "red", label = "Mean");
ax.axvline(median, ls='--', color = "green", label = "Median");
ax.axvline(plus_one_std, color = "black");
ax.axvline(minus_one_std, color = "black");
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_ylabel("Density")
ax.set_xlabel("Doctor Visits")
ax.set_title("Doctor Visits Distribution")
ax.legend()

# %%
kurt = stats.kurtosis(df[col], fisher = False)
print(kurt)
if round(kurt) > 3:
    print("Leptokurtic")
if round(kurt) < 3:
    print("Platykurtic")
if round(kurt) == 3:
    print("Mesokurtic")
# Out:
# 2.9919958083381206
# Mesokurtic

# %%
print("The above graph is discrete with essentially no skew.")
# Out:
# The above graph is discrete with essentially no skew.

# %%
col = 'TotalCharge'

mean = df[col].mean()
std = df[col].std()
median = df[col].median()
plus_one_std = mean + std
minus_one_std = mean - std

ax = sns.histplot(data=df, x='TotalCharge', discrete=False, stat='density', kde = True);

ax.axvline(mean, color = "red", label = "Mean");
ax.axvline(median, ls='--', color = "green", label = "Median");
ax.axvline(plus_one_std, color = "black");
ax.axvline(minus_one_std, color = "black");
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_ylabel("Density")
ax.set_xlabel("Total Charge")
ax.set_title("Total Charge Distribution")
# Out:
# Text(0.5, 1.0, 'Total Charge Distribution')

# %%
kurt = stats.kurtosis(df[col], fisher = False)
print(kurt)
if round(kurt) > 3:
    print("Leptokurtic")
if round(kurt) < 3:
    print("Platykurtic")
if round(kurt) == 3:
    print("Mesokurtic")
# Out:
# 3.2650077463439384
# Mesokurtic

# %%
print("The above graph is continuous with a leftward skew.")
# Out:
# The above graph is continuous with a leftward skew.
